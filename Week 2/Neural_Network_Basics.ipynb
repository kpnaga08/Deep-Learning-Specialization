# %% [markdown]
# # Question 1
#
# What does a neuron compute?
#
# - A neuron compute a linear function $z = Wx + b$ followed by an activation function
#
# - A neuron computes the mean of all features before applying the output to an activation function
#
# - A neuron computes an activation function followed by a linear function $z = Wx + b$
#
# - A neuron computes a function $g$ that scales the input $x$ linearly ($Wx+b$)
#
# **<font color='yellow'>Answer: A neuron compute a linear function $z = Wx + b$ followed by an activation function.</font>**
#
# **<font color='yellow'>Explanation: We generally say that the output of a neuron is $a = g(Wx + b)$ where $g$ is the activation function (sigmoid, tanh, ReLu, ...) </font>**

# %% [markdown]
# # Question 2
#
# Suppose that $\hat{y}=0.9$ and $y=1$. What is the value of the "Logistic Loss"? Choose the best option.
#
# - 0.105
#
# - 0.005
#
# - $+\infty$
#
# - $L(\hat{y},y) = -(\hat{y} log y + (1-\hat{y}) lig (1-y))$
#
# **<font color='yellow'>Answer: 0.105.</font>**
#
# **<font color='yellow'>Explanation: Since $$\mathcal{L}(ŷ, y) = - \left( y \, \log ŷ + (1-y)\ \log ( 1 - ŷ) \right) $$, for the given values we get $$ \mathcal{L}(ŷ, y) = - \left( 1 \, \log 0.9 + 0 \, \log 0.1 \right)$$ </font>**

# %% [markdown]
# # Question 3
#
# Suppose img is a (32,32,3) array, representing a 32x32 image with 3 color channels red, green and blue. How do you reshape this into a column vector $x$?
#
# - $x = \text{img.reshape}((32*32*3,1))$
#
# - $x = \text{img.reshape}((1,32*32,3))$
#
# - $x = \text{img.reshape}((3,32*32))$
#
# - $x = \text{img.reshape}((32*32,3))$
#
# **<font color='yellow'>Answer: $x = \text{img.reshape}((32*32*3,1))$. </font>**

# %% [markdown]
# # Question 4
#
# Consider the following random arrays $a$, $b$, and $c$:
#
# *a=np.random.randn(3,4) # a.shape=(3,4)a.shape = (3, 4)a.shape=(3,4)*
#
# *b=np.random.randn(1,4)b = np.random.randn(1, 4)b=np.random.randn(1,4) # b.shape=(1,4) b.shape = (1, 4)b.shape=(1,4)*
#
# *c=a+b*
#
# What will be the shape of c?
#
# - c.shape = (3,4)
#
# - c.shape = (1,4)
#
# - c.shape = (3,1)
#
# - The computation cannot happen because it is not possible to broadcast more than one dimension.
#
#
# **<font color='yellow'>Answer: c.shape = (3,4).</font>**
#
# **<font color='yellow'>Explanation: Broadcasting is used, so row b is copied 3 times so it can be summed to each row of a. </font>**

# %% [markdown]
# # Question 5
#
# Consider the two following random arrays $a$ and $b$:
#
# *a=np.random.randn(4,3) # a.shape=(4,3)a.shape = (4, 3)a.shape=(4,3)*
#
# *b=np.random.randn(3,2)b = np.random.randn(3, 2)b=np.random.randn(3,2) # b.shape=(3,2)b.shape = (3, 2)b.shape=(3,2)*
#
# *c=a*b*
#
# What will be the shape of $c$?
#
# - c.shape = (4,2)
#
# - c.shape = (3,3)
#
# - The computation cannot happen because the sizes don't match. It's going to be "Error!"
#
# - c.shape = (4,3)
#
# **<font color='yellow'>Answer: The computation cannot happen because the sizes don't match. It's going to be "Error!".</font>**
#
# **<font color='yellow'>Explanation: In numpy the "*" operator indicates element-wise multiplication. It is different from "np.dot()". If you would try "c = np.dot(a,b)" you would get c.shape = (4, 2). </font>**

# %% [markdown]
# # Question 6
#
# Suppose you have $n_{x}$ input features per example. If we decide to use row vectors $\mathbf{x}_{j}$ for the features and $$\begin{bmatrix}
# \mathbf{x}_{1}\\
# \mathbf{x}_{2}\\
# \vdots \\
# \mathbf{x}_{m}\\
# \end{bmatrix}$$
#
# What is the dimension of $X$?
#
# - $(n_{x}, n_{x})$
#
# - $(n_{x}, m)$
#
# - $(1, n_{x})$
#
# - $(m, n_{x})$
#
# **<font color='yellow'>Answer: $(m, n_{x})$.</font>**
#
# **<font color='yellow'>Explanation: Each $\mathbf{x}_j$ has dimension $1 \times $n_x$, $X$ is built stacking all rows together into a $m \times n_x$ array. </font>**

# %% [markdown]
# # Question 7
#
# Recall that *np.dot(a,b)* performs a matrix multiplication on *a* and *b*, whereas *a\*b* performs an element-wise multiplication.
#
# Consider the two following random arrays *a* and *b*:
#
# *a=np.random.randn(12288,150)*
#
# *#a.shape=(12288,150)*
#
# *b=np.random.randn(150,45)*
#
# *# b.shape=(150,45)*
#
# *c=np.dot(a,b)*
#
# What is the shape of *c*?
#
# - c.shape = (12288, 45)
#
# - c.shape = (150,150)
#
# - c.shape = (12288, 150)
#
# - The computation cannot happen because the sizes don't match. It's going to be "Error!"
#
#
# **<font color='yellow'>Answer: c.shape = (12288, 45).</font>**
#
# **<font color='yellow'>Explanation: remember that a np.dot(a, b) has shape (number of rows of a, number of columns of b). The sizes match because:  "number of columns of a = 150 = number of rows of b". </font>**

# %% [markdown]
# # Question 8
#
# Consider the following code snippet:
#
# a.shape=(4,3)
#
# b.shape=(4,1)b.shape = (4, 1)b.shape=(4,1)
#
# for i in range(3):
#
#  for j in range(4):
#
#  c[i][j] = a[j][i] + b[j]
#
# How do you vectorize this?
#
# - c = a + b.T
#
# - c = a.T + b.T
#
# - c = a.T + b
#
# - c = a + b
#
#
# **<font color='yellow'>Answer: c = a.T + b.T.</font>**

# %% [markdown]
# # Question 9
#
# Consider the code snippet:
#
# *a.shape=(3,3)*
#
# *b.shape=(3,3)*
#
# *c =a∗∗2+b.T∗∗2*
#
# Which of the following gives an equivalent output for *c*?
#
# - for i in range(3):
#
#   c[i] = a[i]∗∗2+b[i]∗∗2
#
# - The computation cannot happen because the sizes don't match. It's going to be "Error!"
#
# - for i in range(3):
#
#   for j in range(3):
#
#   c[i][j] = a[i][j]∗∗2+b[j][i]∗∗2
#
# - for i in range(3):
#
#   for j in range(3):
#
#   c[i][j] = a[i][j]∗∗2+b[i][j]∗∗2
#
# **<font color='yellow'>Answer:
#
#   for i in range(3):
#
#   for j in range(3):
#
#   c[i][j] = a[i][j]∗∗2+b[j][i]∗∗2.</font>**
#
# **<font color='yellow'>Explanation: This code squares each entry of a and adds it to the transpose of b square.. </font>**

# %% [markdown]
# # Question 10
#
# Consider the following computational graph:
#
# <figure>
#  <img src="./W2.png"   style="width:800px;height:400px;">
# </figure>
#
# What is the output of $J$?
#
# - $a^{2} - c^{2}$
#
# - $a^{2} + b^{2} - c^{2}$
#
# - $(a - b) * (a - c)$
#
# - $a^{2} - b^{2}$
#
# **<font color='yellow'>Answer: $a^{2} - c^{2}$.</font>**
#
# **<font color='yellow'>Explanation: $$J = r + s = u*v + w*x = (a+b)*(a-b) + (b+c)*(b-c) = a^2 - b^2 + b^2 - c^2 = a^2 - c^2$$ </font>**
